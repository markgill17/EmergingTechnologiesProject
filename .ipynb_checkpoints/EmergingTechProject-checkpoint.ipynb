# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Input
from keras.utils import np_utils

from keras.regularizers import l2
# Out:
# Using TensorFlow backend.

# %%
from keras.utils import np_utils
from tensorflow import keras
import keras
from keras.datasets import mnist

#creating tuples
(image_train, label_train), (image_test, label_test) = mnist.load_data()
print("Original X shape", image_train.shape)
print("Original Y shape", label_train.shape)

# Reshape data.
image_train = image_train.reshape(60000, 784)
image_test  = image_test.reshape(10000, 784)

# cast data to float type. Then we normalize it to give it a common scale
image_train = image_train.astype('float32') 
image_test  = image_test.astype('float32')
image_train /= 255 # Original data is uint8 (0-255). Scale it to range [0,1].
image_test  /= 255

#print statements for test purposes
print("Training X matrix shape", image_train.shape)
print("Testing X matrix shape", image_test.shape)
print (label_train[0])

# Represent the targets as one-hot vectors: e.g. 2 -> [0, 0, 1, 0, 0, 0, 0, 0, 0].
nb_classes = 10
label_train = np_utils.to_categorical(label_train, nb_classes)
label_test  = np_utils.to_categorical(label_test, nb_classes)
print("Training Y matrix shape", label_train.shape)
print("Testing Y matrix shape", label_test.shape)
# Out:
# Original X shape (60000, 28, 28)
# Original Y shape (60000,)
# Training X matrix shape (60000, 784)
# Testing X matrix shape (10000, 784)
# 5
# Training Y matrix shape (60000, 10)
# Testing Y matrix shape (10000, 10)

# %%
# Plot examples of the data.
plt.figure(1, figsize=(14,3))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(image_train[i].reshape(28,28), cmap='gray', interpolation='nearest')
    plt.xticks([])
    plt.yticks([])

# %%
#neural network model layers
model = Sequential()
# input layer
# 
model.add(Dense(256, activation='relu', input_shape=(784,), W_regularizer=l2(0.001))) # Use input_shape=(28,28) for unflattened data.
model.add(Dense(256, activation='relu'))
#model.add(Dropout(0.2)) # Including dropout layer helps avoid overfitting.
model.add(Dense(10, activation='softmax')) # Use softmax layer for multi-class problems.
# Out:
# /home/markg/PycharmProjects/EmergingTechnologiesProject/venv/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(256, activation="relu", input_shape=(784,), kernel_regularizer=<keras.reg...)`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#prints a summary of all the layers
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# ...
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compiling
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#training
history = model.fit(image_train, label_train, batch_size=128, nb_epoch=10, verbose=1)
# Out:
# /home/markg/PycharmProjects/EmergingTechnologiesProject/venv/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/10
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.4332 - accuracy: 0.9210
# Epoch 2/10
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.1990 - accuracy: 0.9665
# Epoch 3/10
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.1588 - accuracy: 0.9725
# Epoch 4/10
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.1352 - accuracy: 0.9770
# Epoch 5/10
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.1241 - accuracy: 0.9789
# Epoch 6/10
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.1210 - accuracy: 0.9792
# Epoch 7/10
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.1094 - accuracy: 0.9824
# Epoch 8/10
# ...

# %%
#printing model accuracy
score = model.evaluate(image_test, label_test, verbose=0)
print('Test cross-entropy loss: %0.5f' % score[0])
print('Test accuracy: %0.2f' % score[1])
# Out:
# Test cross-entropy loss: 0.13425
# Test accuracy: 0.97

# %%
# Plot examples of the data.
plt.figure(1, figsize=(14,3))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(image_train[i].reshape(28,28), cmap='gray', interpolation='nearest')
    plt.xticks([])
    plt.yticks([])

# %%
#saving model to run our drawn digit against
model.save('model.h5')
